# %% [markdown]
# ### Introduction
#
# In the following notebook, I will be aggregating Inside Aribnb's listings and review data from the last year(05/2019 - 05/2020) into a single file

# %% [markdown]
# **Read in libraries**

# %%
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# **Set notebook preferences**

# %%
#Increase number of cols displayed
pd.set_option('display.max_columns', 200)

# %% [markdown]
# **Aggregate and consolidate Listings files**

# %%
#Set path to raw data on local machine
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Airbnb - San Francisco Listings Analysis\Data\01_Raw\SF Airbnb\Raw_Listings_Data'

#Concatenate files in path
listings = pd.concat(map(pd.read_csv, glob.glob(path + '/**')))
# Out:
# C:\Users\kishe\Miniconda3\envs\Airbnb_Listings_Analysis\lib\site-packages\IPython\core\interactiveshell.py:3343: DtypeWarning: Columns (61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Sort columns alphabetically
listings = listings.reindex(sorted(listings.columns), axis=1)

#Drop any duplicate rows
listings.drop_duplicates(inplace = True)

# %%
#Filter last review july 2018 and beyond
listings = listings.loc[listings.last_review >= '2018-07-01']

# %%
#Check
display(listings.head())
# Out:
#                                               access  accommodates  \
# 0  *Full access to patio and backyard (shared wit...             3
# 3                                                NaN             2
# 4  Guests have access to everything listed and sh...             5
# 5                                                NaN             6
# 6  You'll have your own bedroom and private bathr...             3
#
#                                            amenities  availability_30  \
# 0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...                0
# 3  {TV,Internet,Wifi,Kitchen,"Free street parking...               30
# 4  {TV,Internet,Wifi,Kitchen,Heating,"Family/kid ...               30
# 5  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...                0
# 6  {TV,"Cable TV",Internet,Wifi,"Paid parking off...                4
#
#    availability_365  availability_60  availability_90  bathrooms  bed_type  \
# ...

# %% [markdown]
# **Write file to CSV**

# %%
#Print shape of dfs
print('Final shape of aggregated listings data:', listings.shape)

#Set path to write data
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Airbnb - San Francisco Listings Analysis\Data\01_Raw\SF Airbnb'

#Write aggregated data
listings.to_csv(path + '/2020_0715_Aggregated_Listings.csv')
# Out:
# Final shape of aggregated listings data: (126297, 106)
